# %%
import matplotlib.pyplot as plt
from PIL import Image
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch


img = Image.open('/content/drive/MyDrive/Colab Notebooks/Lec11_솔트룩스 특강/images/n01443537_goldfish.jfif')

A_transform = transform.Resize((224, 224))
B_transform = transforms.RandomHorizontalFilp(p=0.5)
C_transform = transforms.RandomVerricalFilp(p=0.5)
D_transform = transforms.RandomCrop((32, 32))
E_transforms = transforms.Grayscale()
F_transforms = transforms.RandomRotation(30)

transforms_list = [A_transform, B_transform, C_transform, D_transform, E_transforms, F_transforms]
transforms_name = ['Resize', 'Horizontalflip', 'verticalfilp', 'crop', 'gray', 'rotation']

fig, subbplots = plt.subplots(1, 7, figsize=(25, 5))
ax = subplots.flat[0]
ax.imshow(img)
ax.set_title('original')

for i in range(6):
  trans_img = transforms_list[i](img)
  ax = subplots.flat[i+1]
  ax.imshow(trans_img)
  ax.set_title(transforms_name[i])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-2785599d0a18> in <module>()
#       1 import torch
# ----> 2 from torch import transform
#       3
#       4 img = Image.open('/content/drive/MyDrive/Colab Notebooks/Lec11_솔트룩스 특강/images/n01443537_goldfish.jfif')
#       5
#
# ImportError: cannot import name 'transform' from 'torch' (/usr/local/lib/python3.7/dist-packages/torch/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
tranform_train = transforms.Compose([
                                     transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     transforms.Normalize((0.49, 0.48, 0.44), (0.20, 0.19, 0.20))
])

tranform_test = transforms.Compose([
                                     transforms.ToTensor(),
                                     transforms.Normalize((0.49, 0.48, 0.44), (0.20, 0.19, 0.20))
])

train.dataset = datasets.CIFIAR10('data', train=True, transform=transform_train, download=True)
test.dataset = datasets.CIFIAR10('data', train=False, transform=transform_test, download=True)

num_classes = len(train_dataset.classes)
batch_size = 64

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=1)
test_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=1)

# %% [markdown]
# # Model

# %%
model = models.resnet18(num_classes = num_classes)
model = model.cuda()
#model = model.to(device) if device = 'cuda'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ec2723136458> in <module>()
# ----> 1 model = models.resnet18(num_classes = num_classes)
#       2 model = model.cuda()
#       3 #model = model.to(device) if device = 'cuda'
#
# NameError: name 'models' is not defined

# %%
from torchsummary import summary

summary(model, (3, 32, 32))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d56d70e5f87a> in <module>()
#       1 from torchsummary import summary
#       2
# ----> 3 summary(model, (3, 32, 32))
#
# NameError: name 'model' is not defined

# %% [markdown]
# # Mixup

# %%
import glob, os, cv2
import numpy as np

mixup_alpha = 1.0

image_list = glob.glob(os.path.join('/content/drive/MyDrive/Colab Notebooks/Lec11_솔트룩스 특강/images', '*.jfif'))
images = []

transform = transforms.Compose([(transforms.Resize((224, 244))), tranforms.ToTensor()])

for i in range(10):
  image = Image.open(image_list[i])
  images.append(transform(image))


Iam = np.random.bera(mixup_alpha, mixup_alpha)
batch_size = images.size()[0]
mixed_x = Iam * images + (1-Iam) * imaegs[0]

flg, subplos = plt.subplots(2, 10, figsize=(25, 5))
for i in range(10):
  ax1 = subplot.flat[i]
  ax2 = subplot.flat[i*10]
