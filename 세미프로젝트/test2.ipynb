# %%
import pandas as pd
import numpy as np
from google.colab import drive
import random
from datetime import datetime
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#태그리스트 만들때 사용할 split함수
def StrtoList(item):
  return item.split(' ')


df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/세미프로젝트/data/Play_list.csv', index_col=0)
df = df.drop(labels=['태그_리스트'], axis=1)
df
# Out:
#            플레이리스트_번호  ...                                          플레이리스트_태그
# index                 ...
# 495785720  495785720  ...  #기분전환 #EDMFloor #stress #청량 #Summer #페스티벌 #Ele...
# 495524162  495524162  ...  #슬기로운의사생활시즌2 #추억 #기분전환 #슬의생 #OST #리메이크 #국내드라마 ...
# 450629235  450629235  ...           #트렌디 #빌보드 #기분전환 #빌보드Hot50 #명곡 #Pop #드라이브
# 495781445  495781445  ...        #침대 #릴렉스 #거품 #연인 #달콤 #로맨틱 #위로 #편안함 #분위기 #휴식
# 495866039  495866039  ...                       #사랑 #밤 #설렘 #인디 #신나는 #감성 #여름밤
# 494969549  494969549  ...    #사랑 #기분전환 #행복 #외출 #기분좋은 #신나는 #출근길 #산책 #드라이브 #여름
# 495080094  495080094  ...         #추억 #기분전환 #시원한 #리메이크 #상쾌한 #명곡 #발라드 #바다 #여름
# 494809787  494809787  ...    #올드재즈 #올드팝 #퇴근 #기분전환 #재즈 #와인 #Pop #일상 #Jazz #여름
# 462088795  462088795  ...   #멜론DJ #상반기 #기분전환 #2021 #가요 #명곡 #발라드 #댄스 #인기 #베스트
# 462121500  462121500  ...    #트렌디 #멜론DJ #상반기 #2021 #명곡 #팝 #인기 #음색 #베스트 #드라이브
# 496323821  496323821  ...     #트렌디 #빌보드 #기분전환 #상반기 #2021 #명곡 #팝 #인기 #음색 #베스트
# ...

# %%
df.to_csv("/content/drive/MyDrive/Colab Notebooks/세미프로젝트/data/Play_list.csv")
