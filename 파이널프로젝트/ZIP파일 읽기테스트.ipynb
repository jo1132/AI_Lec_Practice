# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# #1. zipfile을 읽기위한 모듈 import

# %%
import zipfile
import os

# %% [markdown]
# #2. zip파일 읽기

# %%
my_zip = zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/파이널프로젝트/data/[라벨]apple_fuji_M.zip')
my_zip
# Out:
# <zipfile.ZipFile filename='/content/drive/MyDrive/Colab Notebooks/파이널프로젝트/data/[라벨]apple_fuji_M.zip' mode='r'>

# %% [markdown]
# #3. zip파일 리스트 불러오기

# %% [markdown]
# ##3.1 JSON파일 읽고 DataFrame으로 만들기

# %%
file_list = my_zip.namelist()
file_list
# Out:
# ['apple_fuji_M_1-10_5DI90.json',
#  'apple_fuji_M_1-11_1TOP.json',
#  'apple_fuji_M_1-12_2FR45.json',
#  'apple_fuji_M_1-13_3FR90.json',
#  'apple_fuji_M_1-14_4DI45.json',
#  'apple_fuji_M_1-15_5DI90.json',
#  'apple_fuji_M_1-16_1TOP.json',
#  'apple_fuji_M_1-17_2FR45.json',
#  'apple_fuji_M_1-18_3FR90.json',
#  'apple_fuji_M_1-19_4DI45.json',
#  'apple_fuji_M_1-1_1TOP.json',
#  'apple_fuji_M_1-20_5DI90.json',
#  'apple_fuji_M_1-21_1TOP.json',
#  'apple_fuji_M_1-22_2FR45.json',
#  'apple_fuji_M_1-23_3FR90.json',
#  'apple_fuji_M_1-24_4DI45.json',
#  'apple_fuji_M_1-25_5DI90.json',
#  'apple_fuji_M_1-26_1TOP.json',
#  'apple_fuji_M_1-27_2FR45.json',
#  'apple_fuji_M_1-28_3FR90.json',
#  'apple_fuji_M_1-29_4DI45.json',
#  'apple_fuji_M_1-2_2FR45.json',
#  'apple_fuji_M_1-30_5DI90.json',
#  'apple_fuji_M_1-31_1TOP.json',
#  'apple_fuji_M_1-32_2FR45.json',
#  'apple_fuji_M_1-33_3FR90.json',
#  'apple_fuji_M_1-34_4DI45.json',
#  'apple_fuji_M_1-35_5DI90.json',
# ...

# %%
test_read = my_zip.read(file_list[0])
test_read
# Out:
# b'{\n    "group_no": 601032001000,\n    "no": 601032001028,\n    "img_no": 28,\n    "catecode": "060103",\n    "cate1": "\xec\x82\xac\xea\xb3\xbc",\n    "cate2": "\xeb\xb6\x80\xec\x82\xac",\n    "cate3": "\xec\x83\x81",\n    "width": "8.6",\n    "height": "7.5",\n    "weight": "290",\n    "copyright": "",\n    "repo": "\xec\x82\xac\xea\xb3\xbc/\xeb\xb6\x80\xec\x82\xac/\xec\x83\x81/1",\n    "identifier": "/\xec\x82\xac\xea\xb3\xbc_\xeb\xb6\x80\xec\x82\xac_\xec\x83\x81_10_5DI90.png",\n    "format": "png",\n    "img_height": 1000,\n    "img_width": 1000,\n    "date": "2021-04-12 01:04:30",\n    "resolution": 1000000,\n    "bit": "24",\n    "f_stop": "8",\n    "camera_model": "ILCE-6400",\n    "camera_software": "PhotoScape",\n    "exposure_time": "0.016666666666666666",\n    "iso": "400",\n    "focal_length": "16",\n    "full_aperture": "3.6171875",\n    "white_balance": "1",\n    "gps_lng": "",\n    "gps_lat": "",\n    "truncated": "on",\n    "angle_direction": "top",\n    "verticality
# ...

# %%
import pandas as pd

df = pd.read_json(test_read)
df
# Out:
#           group_no            no  ...  horizontality_angle  bndbox
# xmax  601032001000  601032001028  ...                   90    1000
# xmin  601032001000  601032001028  ...                   90       0
# ymax  601032001000  601032001028  ...                   90    1000
# ymin  601032001000  601032001028  ...                   90       0
#
# [4 rows x 34 columns]

# %% [markdown]
# ##3.2 이미지파일 읽어보기

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 성공 코드

# %%
my_zip_image = zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/파이널프로젝트/data/apple_fuji_M.zip')
image_list = my_zip_image.namelist()
byte_image = my_zip_image.read(image_list[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-6e20451c7b11> in <module>()
# ----> 1 my_zip_image = zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/파이널프로젝트/data/apple_fuji_M.zip')
#       2 image_list = my_zip_image.namelist()
#       3 byte_image = my_zip_image.read(image_list[0])
#
# /usr/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1238             while True:
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
#    1241                 except OSError:
#    1242                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/파이널프로젝트/data/apple_fuji_M.zip'

# %%
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
import io
import binascii

byte_image = my_zip_image.read(image_list[0])

stream = io.BytesIO(byte_image)
img = Image.open(stream)
plt.imshow(img)

# %%
len(byte_image)
# Out:
# 1555312

# %%
resize_image = img.resize((512, 512))
plt.imshow(resize_image)

# %%
resize_image = img.resize((256, 256))
plt.imshow(resize_image)

# %%
resize_image = img.resize((128, 128))
plt.imshow(resize_image)
