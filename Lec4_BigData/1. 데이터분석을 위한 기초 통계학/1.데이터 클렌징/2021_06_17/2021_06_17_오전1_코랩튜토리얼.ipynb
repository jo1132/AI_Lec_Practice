# %% [markdown]
# # 1. 대표값
# > 대표값이란 전체를 대표할 수 있는 값을 의미한다.
# * 주문하면 얼마나 걸리나요?
# * 요즘 초봉은 얼마나 하나요?

# %% [markdown]
# ## 1.1 대표값의 종류

# %% [markdown]
# ### 1.1.1 평균
# > 평균은 여러 종류가 있으나 간단하게 몇가지만 알아보도록 하겠습니다.
# * 산술평균
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #2. 표준편차와 분산
