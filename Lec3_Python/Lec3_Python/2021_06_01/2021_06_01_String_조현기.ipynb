# %% [markdown]
# Capitalize() 메소드

# %%
txt = "hello, and welcome to my world."

x = txt.capitalize()

print(x)
# Out:
# Hello, and welcome to my world.

# %% [markdown]
# casefold() : Converts string into lower case,
# This method is similar to the lower() method, but the casefold() method is stronger,

# %%
txt = "Hello, And Welcom To My World!"
x = txt.casefold()
print(x)
# Out:
# hello, and welcom to my world!

# %% [markdown]
# center():Returns a centered string (center align string)

# %%
txt = "banana"
x = txt.center(20)
print(x)
len(x)
# Out:
#        banana
# 20

# %% [markdown]
# count(): Returns the number of times a specified value occurs in a string,
# string count

# %%
txt = "I love apples, apple are my favorite fruit"
x = txt.count("apple")
print(x)
# Out:
# 2

# %% [markdown]
# encode(): 	Returns an encoded version of the string

# %%
txt = "My name is Ståle"
x = txt.encode()
print(x)
# Out:
# b'My name is St\xc3\xa5le'

# %%
y = x.decode("CP949")
print(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-c8920e76a187> in <module>()
# ----> 1 y = x.decode("CP949")
#       2 print(y)
#
# AttributeError: 'tuple' object has no attribute 'decode'

# %% [markdown]
# endswith(): Returns true if the string ends with the specified value

# %%
txt = "Hello, welcome to my world."
x=txt.endswith(".")
print(x)
# Out:
# True

# %% [markdown]
# expandtabs():	Sets the tab size of the string
# 사이사이 띄어쓰기

# %%
txt = "H\te\tl\tl\to"
x = txt.expandtabs(2)
print(x)
# Out:
# H e l l o

# %% [markdown]
# find(): Searches the string for a specified value and returns the position of where it was found
# 시작하는 인덱스를 반환

# %%
txt = "Hello, welcome to my world."
x = txt.find("welcom")
print(x)
# Out:
# 7

# %% [markdown]
# isalnul(): Returns True if all characters in the string are alphanumeric
# 영숫자인지 확인

# %%
txt = "Company12"
x = txt.isalnum()
print(x)
# Out:
# True

# %% [markdown]
# isalpha(): Returns True if all characters in the string are in the alphabet
# 알파벳인지 확인

# %%
txt = "C1o2m3p4a5n6y7X"
for i in txt:
  if(i.isalpha()):
    print(i)
# Out:
# C
# o
# m
# p
# a
# n
# y
# X

# %% [markdown]
# isdecimal(): 	Returns True if all characters in the string are decimals
# 10진수인지 확인

# %%
txt = "\u0033" #unicode for 3
x = txt.isdecimal()
print(x)
# Out:
# True

# %% [markdown]
# isdigit(): Returns True if all characters in the string are digits 숫자인지 확인

# %%
txt = "50800"
x = txt.isdigit()
print(x)
# Out:
# True

# %% [markdown]
# isidentifier(): 	Returns True if the string is an identifier
#
# A string is considered a valid identifier if it only contains alphanumeric letters (a-z) and (0-9), or underscores (_). A valid identifier cannot start with a number, or contain any spaces.

# %%
txt = "jhk"
x = txt.isidentifier()
print(x)
# Out:
# True

# %% [markdown]
# islower(): Returns True if all characters in the string are lower case
# 소문자인지 확인

# %%
txt = "hello world!"
x = txt.islower()
print(x)
# Out:
# True

# %% [markdown]
# isnumeric(): 	Returns True if all characters in the string are numeric 숫자인지 확인

# %%
txt = "565543"
x = txt.isnumeric()
print(x)
# Out:
# True

# %% [markdown]
# isprintalbe(): Returns True if all characters in the string are printable

# %%
txt = "Hello! Are you #1?"
txt2 = "Hello!\nAre you #1?"
x = txt.isprintable()
y = txt2.isprintable()
print(x)
print(y)
# Out:
# True
# False

# %% [markdown]
# isspace(): Returns True if all characters in the string are whitespaces

# %%
txt = "   "
x = txt.isspace()
print(x)
# Out:
# True

# %% [markdown]
# istitle(): Returns True if the string follows the rules of a title,
#
# The istitle() method returns True if all words in a text start with a upper case letter, AND the rest of the word are lower case letters, otherwise False.

# %%
txt = "Hello, And Welcome To My World!"
x = txt.istitle()
print(x)
# Out:
# True

# %% [markdown]
# isupper(): 	Returns True if all characters in the string are upper case

# %%
txt = "THIS IS NOW!"
x = txt.isupper()
print(x)
# Out:
# True

# %% [markdown]
# join(): 	Joins the elements of an iterable to the end of the string

# %%
myTuple = ("John", "Peter", "Vicky")
x = "#".join(myTuple)
print(x)
# Out:
# John#Peter#Vicky

# %% [markdown]
# ljust(): Returns a left justified version of the string

# %%
txt = "banana"
x = txt.ljust(20)
print(x, "is my favorite fruit.")
# Out:
# banana               is my favorite fruit.

# %%
txt = "banana"
x = txt.ljust(20, "O")
print(x, "is my favorite fruit.")
# Out:
# bananaOOOOOOOOOOOOOO is my favorite fruit.

# %% [markdown]
# lower(): Converts a string into lower case 소문자로 전부 바꿔버림

# %%
txt = "Hello my FRIENDS"
x = txt.lower()
print(x)
# Out:
# hello my friends

# %% [markdown]
# lstrip(): 	Returns a left trim version of the string
# 왼쪽 공백을 하나남기고 다 삭제

# %%
txt = "     banana     *"
x = txt.lstrip()
print("of all fruit", x, "is my favorite")
# Out:
# of all fruit banana     * is my favorite

# %%
txt = ",,,,,ssaaww.....banana"
x = txt.lstrip(",.asw")
print(x)
# Out:
# banana

# %% [markdown]
# maketrans(): Returns a translation table to be used in translations
# 글자를 바꿔준다

# %%
txt = "Hello Sam!"
mytable = txt.maketrans("S", "P")
print(txt.translate(mytable))
# Out:
# Hello Pam!

# %%
txt = "Good night Sam!"
x = "mSa"
y = "eJo"
z = "odnght"
mytable = txt.maketrans(x, y, z)
print(txt.translate(mytable))
# Out:
# G i Joe!

# %% [markdown]
# partition(): 	Returns a tuple where the string is parted into three parts

# %%
txt = "I could eat bananas all day"
x = txt.partition("bananas")
print(x)
# Out:
# ('I could eat ', 'bananas', ' all day')
