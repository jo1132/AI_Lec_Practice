# %% [markdown]
# ###**뷰티풀수프 퀵스타트**

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

print(soup.prettify())  # 보기힘든 html_doc을 보기 좋게 만들어 줬다.
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
#html_doc.    #일반 문자열처럼만 사용 가능

#soup.      #Beatifulsoup의 기능을 사용 가능하다.
print(soup.title)  #태그포함 타이틀 가져오기
print(soup.title.name)  #태그이름 가져오기
print(soup.title.text)  #태그를 뺀 text만 가져오기

print("\n", soup.title.parent) #자신과 부모태그, 형제까지 찾아오기
print("\n", soup.title.parent.parent)
# Out:
# <title>The Dormouse's story</title>
# title
# The Dormouse's story
#
#  <head><title>The Dormouse's story</title></head>
#
#  <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
soup.p   #제일 처음나오는 p태그 가져옴
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.p['class']   #p태그에 class있는애 가져오기 (다만 리스트형으로 반환된다.)
# Out:
# ['title']

# %%
soup.a   #첫번째 만난 a태그 가져오기
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a')  #이 또한 리스트형으로 반환
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find_all('p')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
for idx, i in enumerate(soup.find_all('a')):
  print("idx[", idx, "] =",i)
# Out:
# idx[ 0 ] = <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# idx[ 1 ] = <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# idx[ 2 ] = <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
soup.find(id = "link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
type(soup.find(id = "link3"))
# Out:
# bs4.element.Tag

# %%
for link in soup.find_all('a'):
  print(link.get("href"))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
soup.find_all('a')[0].get("href")
# Out:
# 'http://example.com/elsie'

# %%
soup.get_text()  ##태그 다 빼고 순수 텍스트만 가져온다.
# Out:
# "The Dormouse's story\n\nThe Dormouse's story\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n...\n"

# %%
head_tag = soup.head
head_tag
# <head><title>The Dormouse's story</title></head>

head_tag.contents
# [<title>The Dormouse's story</title>]

title_tag = head_tag.contents[0]
title_tag
# <title>The Dormouse's story</title>
title_tag.contents
# ['The Dormouse's story']
# Out:
# ["The Dormouse's story"]

# %%
import re
for tag in soup.find_all(re.compile("^b")):     #b로 시작되는 태그는 모두 출력
  print(tag.name)
# Out:
# body
# b

# %%
for tag in soup.find_all(re.compile("t")):  #t가 들어가는 태그 이름 다 가져오기
  print(tag.name)
# Out:
# html
# title

# %%
soup.find_all(["a", 'b'])  #b태그와 a태그 모두 찾기
# Out:
# [<b>The Dormouse's story</b>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
# soup.find_all("df", {"class" : "??"})   #네이버 뉴스 긁어올때 사용했던 find_all

# %%
soup.find_all(id=True)  #id = True 아이디 있는애만, False: 전체 다 뽑아오기
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
data_soup = BeautifulSoup('<div data-foo="value">foo!</div>', 'html.parser')
data_soup.find_all(attrs={"data-foo": "value"})  # dict형으로 나와야한다.
# Out:
# [<div data-foo="value">foo!</div>]

# %%
#body > p.title
soup.select("p:nth-of-type(3)")
# Out:
# [<p class="story">...</p>]

# %%
soup.select("body a")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
