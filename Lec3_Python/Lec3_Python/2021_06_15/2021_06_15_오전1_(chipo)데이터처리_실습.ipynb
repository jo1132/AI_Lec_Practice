# %% [markdown]
# #https://www.kaggle.com/navneethc/chipotle

# %% [markdown]
# ### (문1. 필요한 라이브러리 import) ###
# 1. pandas, numpy, mapplotlib, seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#라이브러리 version
# import 설치가 필요할 떄
# 아나콘다  prompt -> pip install 라이브러리명
#마지막 방법으로 *.whl 설치 파일을 찾아서 다운로드후 설치

# %% [markdown]
# ### (문2. 데이터 읽어오기 ) ###
# 1. 데이터를 읽어서 df를 만들기 -> chip
# 2. df 데이터를 학인
#  - 데이터가 몇건인지 (행과 열) -> df.shape
#  - 처음 5건? 마지막 5건? -> head(), tail()
#  - 컬럼명은? df구조는? 결측치는?  -> df.columns(), df.info(), df.isnull().sum()
#  - 요약 통계는? ->  df.describe()
#
# 3. 데이터는
#  - url : https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
#  - 단축  url : https://url.kr/ohnxci

# %%
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")  #한글이 깨지면 , encoding= "CP949", "EUC-LR", "utf-8"
                                                                                                          #index_col = 인덱스로 사용할 컬럼 인덱스
                                                                                                          #skiprow= 앞 몇줄을 스킵하고 읽겠다.
df
# Out:
#       order_id  ...  item_price
# 0            1  ...      $2.39
# 1            1  ...      $3.39
# 2            1  ...      $3.39
# 3            1  ...      $2.39
# 4            2  ...     $16.98
# ...        ...  ...         ...
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [4622 rows x 5 columns]

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.head()
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %%
df.tail()
# Out:
#       order_id  ...  item_price
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [5 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
df["item_name"].value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
df["item_name"].value_counts().count()
# Out:
# 50

# %% [markdown]
# ### (문4. 상품 가격이 $10 이상인 제품은 몇개인가?) ###
#
# 1. item_price에서 $를 제외한 숫자로 새로운 변수를 만든다.("new_price")
# 2. new_price에서 10보다 크면서 quantity가 1개인제품
# 3. 중복 제외한 숫자

# %%
df[df["item_price"] > "10"]
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price]
# Index: []

# %%
df["item_price"]
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
temp = df.iloc[0, 4]
temp[1:-1]
# Out:
# '2.39'

# %%
df["new_price"] =df["item_price"].str[1:-1]
df["new_price"]
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: new_price, Length: 4622, dtype: object

# %%
#df['new_price'] = 0
df['new_price_2'] = 0
for row in range(0, len(df)):
  df.iloc[row, 6] = df.iloc[row, 4][1:-1]

# %%
df["new_price_2"]
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: new_price_2, Length: 4622, dtype: object

# %%
df['new_price'].astype(float)  # type을 float로 해서 보여줌
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: new_price, Length: 4622, dtype: float64

# %%
df[df['new_price'].astype(float) > 10]
# Out:
#       order_id  quantity           item_name  ... item_price new_price new_price_2
# 4            2         2        Chicken Bowl  ...    $16.98      16.98       16.98
# 5            3         1        Chicken Bowl  ...    $10.98      10.98       10.98
# 7            4         1       Steak Burrito  ...    $11.75      11.75       11.75
# 13           7         1        Chicken Bowl  ...    $11.25      11.25       11.25
# 23          12         1     Chicken Burrito  ...    $10.98      10.98       10.98
# ...        ...       ...                 ...  ...        ...       ...         ...
# 4610      1830         1       Steak Burrito  ...    $11.75      11.75       11.75
# 4611      1830         1      Veggie Burrito  ...    $11.25      11.25       11.25
# 4617      1833         1       Steak Burrito  ...    $11.75      11.75       11.75
# 4618      1833         1       Steak Burrito  ...    $11.75      11.75       11.75
# ...

# %%
(df['new_price'].astype(float)>=10) & (df['quantity'] == 1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4617     True
# 4618     True
# 4619     True
# 4620    False
# 4621    False
# Length: 4622, dtype: bool

# %%
item_filter = (df['new_price'].astype(float)>=10) & (df['quantity'] == 1)

# %%
df[(df['new_price'].astype(float)>=10) & (df['quantity'] == 1)]
# Out:
#       order_id  quantity           item_name  ... item_price new_price new_price_2
# 5            3         1        Chicken Bowl  ...    $10.98      10.98       10.98
# 7            4         1       Steak Burrito  ...    $11.75      11.75       11.75
# 13           7         1        Chicken Bowl  ...    $11.25      11.25       11.25
# 23          12         1     Chicken Burrito  ...    $10.98      10.98       10.98
# 39          19         1       Barbacoa Bowl  ...    $11.75      11.75       11.75
# ...        ...       ...                 ...  ...        ...       ...         ...
# 4610      1830         1       Steak Burrito  ...    $11.75      11.75       11.75
# 4611      1830         1      Veggie Burrito  ...    $11.25      11.25       11.25
# 4617      1833         1       Steak Burrito  ...    $11.75      11.75       11.75
# 4618      1833         1       Steak Burrito  ...    $11.75      11.75       11.75
# ...

# %%
df[item_filter]
# Out:
#       order_id  quantity           item_name  ... item_price new_price new_price_2
# 5            3         1        Chicken Bowl  ...    $10.98      10.98       10.98
# 7            4         1       Steak Burrito  ...    $11.75      11.75       11.75
# 13           7         1        Chicken Bowl  ...    $11.25      11.25       11.25
# 23          12         1     Chicken Burrito  ...    $10.98      10.98       10.98
# 39          19         1       Barbacoa Bowl  ...    $11.75      11.75       11.75
# ...        ...       ...                 ...  ...        ...       ...         ...
# 4610      1830         1       Steak Burrito  ...    $11.75      11.75       11.75
# 4611      1830         1      Veggie Burrito  ...    $11.25      11.25       11.25
# 4617      1833         1       Steak Burrito  ...    $11.75      11.75       11.75
# 4618      1833         1       Steak Burrito  ...    $11.75      11.75       11.75
# ...

# %%
df[item_filter].shape
# Out:
# (997, 7)

# %%
len(df[item_filter])
# Out:
# 997

# %%
 #중복 제거 하기
df[item_filter].drop_duplicates(["item_name"])[["item_name", "quantity", "new_price"]]
# Out:
#                   item_name  quantity new_price
# 5              Chicken Bowl         1     10.98
# 7             Steak Burrito         1     11.75
# 23          Chicken Burrito         1     10.98
# 39            Barbacoa Bowl         1     11.75
# 57           Veggie Burrito         1     11.25
# 62              Veggie Bowl         1     11.25
# 79       Chicken Soft Tacos         1     11.25
# 90               Steak Bowl         1     11.75
# 93         Carnitas Burrito         1     11.75
# 97            Carnitas Bowl         1     11.75
# 130        Barbacoa Burrito         1     11.75
# 168   Barbacoa Crispy Tacos         1     11.75
# 186       Veggie Salad Bowl         1     11.25
# 250           Chicken Salad         1     10.98
# 365    Chicken Crispy Tacos         1     11.25
# 606        Steak Salad Bowl         1     11.89
# 738       Veggie Soft Tacos         1     11.25
# 988     Barbacoa Soft Tacos         1     11.75
# 1008  Carnitas Crispy Tacos         1     11.75
# ...

# %%
df[item_filter].drop_duplicates(["item_name"]).shape
# Out:
# (25, 7)

# %% [markdown]
# ### (실습, item_name, choice_description, new_price로 구성된 품목별 단가 chip_price df를 만들기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")

df["new_price"] = df['item_price'].str[1:-1]   #new_price만들기

#price가 10달러 이상이고 , quantity가 1개인항목만 따로 고르기
df2 = df[(df["new_price"].astype(float) > 10) & (df['quantity'] == 1)]

#중복 제거하기
df2 = df2.drop_duplicates(['item_name'])

#df2에서  상품명, 초이스 뭐시깽이, 가격으로만 구성된 df만들기
chip_price = df2[["item_name", 'choice_description', 'new_price']]

#chip_price.reset_index() #인덱스 다시생성
chip_price = chip_price.reset_index(drop=True) #기존인덱스는 삭제
chip_price
# Out:
#                 item_name  ... new_price
# 0            Chicken Bowl  ...     10.98
# 1           Steak Burrito  ...     11.75
# 2         Chicken Burrito  ...     10.98
# 3           Barbacoa Bowl  ...     11.75
# 4          Veggie Burrito  ...     11.25
# 5             Veggie Bowl  ...     11.25
# 6      Chicken Soft Tacos  ...     11.25
# 7              Steak Bowl  ...     11.75
# 8        Carnitas Burrito  ...     11.75
# 9           Carnitas Bowl  ...     11.75
# 10       Barbacoa Burrito  ...     11.75
# 11  Barbacoa Crispy Tacos  ...     11.75
# 12      Veggie Salad Bowl  ...     11.25
# 13          Chicken Salad  ...     10.98
# 14   Chicken Crispy Tacos  ...     11.25
# 15       Steak Salad Bowl  ...     11.89
# 16      Veggie Soft Tacos  ...     11.25
# 17    Barbacoa Soft Tacos  ...     11.75
# 18  Carnitas Crispy Tacos  ...     11.75
# 19    Carnitas Salad Bowl  ...     11.89
# 20     Chicken Salad Bowl  ...     11.25
# 21    Barbacoa Salad Bowl  ...     11.89
# ...

# %% [markdown]
# ### (Chip_price에서 item_name순으로 sort) ###

# %%
#인덱스로 정렬할땐 : .sort_index()

#열로 정렬할땐
chip_price = chip_price.sort_values(by= "item_name").reset_index(drop=True)
chip_price
# Out:
#                 item_name  ... new_price
# 0           Barbacoa Bowl  ...     11.75
# 1        Barbacoa Burrito  ...     11.75
# 2   Barbacoa Crispy Tacos  ...     11.75
# 3     Barbacoa Salad Bowl  ...     11.89
# 4     Barbacoa Soft Tacos  ...     11.75
# 5           Carnitas Bowl  ...     11.75
# 6        Carnitas Burrito  ...     11.75
# 7   Carnitas Crispy Tacos  ...     11.75
# 8     Carnitas Salad Bowl  ...     11.89
# 9     Carnitas Soft Tacos  ...     11.75
# 10           Chicken Bowl  ...     10.98
# 11        Chicken Burrito  ...     10.98
# 12   Chicken Crispy Tacos  ...     11.25
# 13          Chicken Salad  ...     10.98
# 14     Chicken Salad Bowl  ...     11.25
# 15     Chicken Soft Tacos  ...     11.25
# 16             Steak Bowl  ...     11.75
# 17          Steak Burrito  ...     11.75
# 18     Steak Crispy Tacos  ...     11.75
# 19       Steak Salad Bowl  ...     11.89
# 20       Steak Soft Tacos  ...     11.75
# 21            Veggie Bowl  ...     11.25
# ...

# %% [markdown]
# ### 가장 비싼 품목(제품)은? ###

# %%
chip_price.sort_values(by="new_price", ascending=False).head()
# Out:
#               item_name  ... new_price
# 8   Carnitas Salad Bowl  ...     11.89
# 3   Barbacoa Salad Bowl  ...     11.89
# 19     Steak Salad Bowl  ...     11.89
# 0         Barbacoa Bowl  ...     11.75
# 16           Steak Bowl  ...     11.75
#
# [5 rows x 3 columns]

# %% [markdown]
# ### 원래 데이터 에서 veggie Salad Bowl은 몇번 팔렸나? ###

# %%
df[df["item_name"] == "Veggie Salad Bowl"].count()
# Out:
# order_id              18
# quantity              18
# item_name             18
# choice_description    18
# item_price            18
# new_price             18
# dtype: int64

# %%
df[df["item_name"] == "Veggie Salad Bowl"].shape
# Out:
# (18, 6)

# %%
len(df[df['item_name'] == "Veggie Salad Bowl"])
# Out:
# 18

# %%
df[df.item_name == "Veggie Salad Bowl"].shape
# Out:
# (18, 6)

# %%
df[df.item_name == "Veggie Salad Bowl"].quantity.sum() # 판매한 총 개수?
# Out:
# 18

# %% [markdown]
# ###(chipo에서 Canned Soda를 1개이상 주문한 건수는?)

# %%
df[(df.item_name == "Canned Soda") & (df.quantity > 1)].count()
# Out:
# order_id              20
# quantity              20
# item_name             20
# choice_description    20
# item_price            20
# new_price             20
# dtype: int64

# %%
df[(df.item_name == "Canned Soda")]
# Out:
#       order_id  quantity    item_name choice_description item_price new_price
# 18           9         2  Canned Soda           [Sprite]     $2.18       2.18
# 28          14         1  Canned Soda       [Dr. Pepper]     $1.09       1.09
# 51          23         2  Canned Soda     [Mountain Dew]     $2.18       2.18
# 53          24         1  Canned Soda           [Sprite]     $1.09       1.09
# 107         47         1  Canned Soda       [Dr. Pepper]     $1.09       1.09
# ...        ...       ...          ...                ...        ...       ...
# 3897      1562         1  Canned Soda     [Mountain Dew]     $1.09       1.09
# 3926      1575         1  Canned Soda       [Dr. Pepper]     $1.09       1.09
# 3936      1578         1  Canned Soda  [Diet Dr. Pepper]     $1.09       1.09
# 4008      1604         1  Canned Soda        [Diet Coke]     $1.09       1.09
# 4051      1621         1  Canned Soda           [Sprite]     $1.09       1.09
#
# [104 rows x 6 columns]

# %%
df[df.item_name == "Canned Soda"].quantity.sum() # 판매한 총 개수?
# Out:
# 126

# %% [markdown]
# ### 아까만든 chip_price를 csv파일로 저장

# %%
chip_price.shape
# Out:
# (25, 3)

# %%
#인덱스가 또만들어짐
#chip_price.to_csv("/content/drive/MyDrive/Colab Notebooks/2021_06_15/chip_price.csv")

#인덱스 없이 저장
chip_price.to_csv("/content/drive/MyDrive/Colab Notebooks/2021_06_15/chip_price.csv", index=False)

# %%
#인덱스를 넣었을때, 중복으로 만들어진 인덱스 빼고 읽기
#pd.read_csv("/content/drive/MyDrive/Colab Notebooks/2021_06_15/chip_price.csv").head(1)

pd.read_csv("/content/drive/MyDrive/Colab Notebooks/2021_06_15/chip_price.csv")
# Out:
#                 item_name  ... new_price
# 0           Barbacoa Bowl  ...     11.75
# 1        Barbacoa Burrito  ...     11.75
# 2   Barbacoa Crispy Tacos  ...     11.75
# 3     Barbacoa Salad Bowl  ...     11.89
# 4     Barbacoa Soft Tacos  ...     11.75
# 5           Carnitas Bowl  ...     11.75
# 6        Carnitas Burrito  ...     11.75
# 7   Carnitas Crispy Tacos  ...     11.75
# 8     Carnitas Salad Bowl  ...     11.89
# 9     Carnitas Soft Tacos  ...     11.75
# 10           Chicken Bowl  ...     10.98
# 11        Chicken Burrito  ...     10.98
# 12   Chicken Crispy Tacos  ...     11.25
# 13          Chicken Salad  ...     10.98
# 14     Chicken Salad Bowl  ...     11.25
# 15     Chicken Soft Tacos  ...     11.25
# 16             Steak Bowl  ...     11.75
# 17          Steak Burrito  ...     11.75
# 18     Steak Crispy Tacos  ...     11.75
# 19       Steak Salad Bowl  ...     11.89
# 20       Steak Soft Tacos  ...     11.75
# 21            Veggie Bowl  ...     11.25
# ...
