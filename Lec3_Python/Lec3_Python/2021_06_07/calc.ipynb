# %%
def add(a,b):
  return a+b
def mul(a,b):
  return a*b
def sub(a,b):
  return a-b

if __name__ == '__main__':
  print("**main**")
  print(add(10, 20))
  print(mul(10, 20))
  print(sub(10, 20))
# Out:
# **main**
# 30
# 200
# -10

# %%
import calc

# %%
add(1, 2)
# Out:
# 3

# %%
mul(10, 20)
# Out:
# 200

# %%
sub(100, 10)
# Out:
# 90

# %%
! calc.py
# Out:
# /bin/bash: calc.py: command not found

# %%
# !python calc.py
# Out:
# **main**
# 30
# 200
# -10
