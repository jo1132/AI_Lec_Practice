# %%
import mod1 as mod

# %%
x = mod.MyClass()

# %%
x.length
# Out:
# 10

# %%
x.size
# Out:
# 5

# %%
x.sum(1, 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-4f3b3705ea41> in <module>()
# ----> 1 x.sum(1, 10)
#
# TypeError: sum() takes 2 positional arguments but 3 were given

# %%
import main2
# Out:
# import 되어 실행
# __main__ =  main2
