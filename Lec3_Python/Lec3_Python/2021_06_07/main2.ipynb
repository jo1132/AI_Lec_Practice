# %%
if __name__ == "__main__":  #시스템 변수이기 때문에 오류가 나지 않는다.
  print("모듈 시작")        #이것 자체를 실행하면 모듈시작이 출력될 것이고, 
else:                       # 다른곳에서 불려 사용되면 아래가 출력될 것이다.
  print("import 되어 실행")
  print("__main__ = ", __name__)
# Out:
# 모듈 시작

# %%
import main2

# %%
# !python main2.py      #!를 앞에 쓰면 실행모드로 들어간다
# Out:
# 모듈 시작
